# %% [markdown]
# ### This notebook deals with the improvements of the titanic survival prediction

# %% [markdown]
# # 1. Setup data

# %%
import pandas as pd
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')

# %% [markdown]
# # 2. Data Exploration and pre-processing

# %% [markdown]
# A case of accident is being discussed. By a natural understanding, 'Name' won't have any effect on the nature of survival. Therefore, 'Name' has to be dropped.

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
features_train = train_df.drop(['Name'], axis = 1)
features_test = test_df.drop(['Name'], axis = 1)

# %% [markdown]
# ### 2.1 Missing data
#
# Age could be a factor which would affect the survival. It is missing in 19% of data, we can simply drop those records.
# Cabin is missing in a lot of records almost 77% records. We can treat it as NA.
# 2 records of EMbarked can be dropped

# %%
total1 = features_train.isnull().sum().sort_values(ascending = False)
percent1 = (features_train.isnull().sum()/features_train.isnull().count()).sort_values(ascending = False)
missingData_df_train = pd.concat([total1,percent1], axis = 1)
missingData_df_train
# Out:
#                0         1
# Cabin        687  0.771044
# Age          177  0.198653
# Embarked       2  0.002245
# Fare           0  0.000000
# Ticket         0  0.000000
# Parch          0  0.000000
# SibSp          0  0.000000
# Sex            0  0.000000
# Pclass         0  0.000000
# Survived       0  0.000000
# PassengerId    0  0.000000

# %%
total2 = features_test.isnull().sum().sort_values(ascending = False)
percent2 = (features_test.isnull().sum()/features_test.isnull().count()).sort_values(ascending = False)
missingData_df_test = pd.concat([total2,percent2], axis = 1)
missingData_df_test
# Out:
#                0         1
# Cabin        327  0.782297
# Age           86  0.205742
# Fare           1  0.002392
# Embarked       0  0.000000
# Ticket         0  0.000000
# Parch          0  0.000000
# SibSp          0  0.000000
# Sex            0  0.000000
# Pclass         0  0.000000
# PassengerId    0  0.000000

# %%
#drop Age
features_train.drop(features_train[features_train.Age.isnull()].index.tolist(), axis = 0, inplace = True)
features_test.Age.fillna(features_test.Age.mean, inplace=True)

features_train.Cabin.fillna('NA', inplace = True)
features_test.Cabin.fillna('NA', inplace = True)

features_train.drop(features_train[features_train.Embarked.isnull()].index.tolist(), axis = 0, inplace = True)
features_test.Fare.fillna(features_test.Fare.mean, inplace=True)

# %% [markdown]
# ### 2.2 Ensuring uniformity of unique values in categorical variables
#
# For SibSp (Number of siblings/spouses) we have a value of 8 for 1 record in Test set. This value is not present in the training set.
# We consider this number as highest, so we update it to the highest value in the training set so that it would be considered

# %%
features_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
features_test[features_test.SibSp == 8]
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# F:\InstalledPrograms\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     lines = output.splitlines()
#     697     with p.group():
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\core\frame.py in __repr__(self)
#     685             line_width=width,
#     686             max_colwidth=max_colwidth,
# --> 687             show_dimensions=show_dimensions,
#     688         )
#     689
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     818                 line_width=line_width,
#     819             )
# --> 820             return formatter.to_string(buf=buf, encoding=encoding)
#     821
#     822     # ----------------------------------------------------------------------
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self, buf, encoding)
#     914         encoding: Optional[str] = None,
#     915     ) -> Optional[str]:
# --> 916         return self.get_result(buf=buf, encoding=encoding)
#     917
#     918     def to_latex(
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in write_result(self, buf)
#     823         else:
#     824
# --> 825             strcols = self._to_str_columns()
#     826             if self.line_width is None:  # no need to wrap around just print
#     827                 # the whole frame
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _to_str_columns(self)
#     759                     self.col_space or 0, *(self.adj.len(x) for x in cheader)
#     760                 )
# --> 761                 fmt_values = self._format_col(i)
#     762                 fmt_values = _make_fixed_width(
#     763                     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_col(self, i)
#     954             na_rep=self.na_rep,
#     955             space=self.col_space,
# --> 956             decimal=self.decimal,
#     957         )
#     958
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1258         for i, v in enumerate(vals):
#    1259             if not is_float_type[i] and leading_space:
# -> 1260                 fmt_values.append(" {v}".format(v=_format(v)))
#    1261             elif is_float_type[i]:
#    1262                 fmt_values.append(float_format(v))
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1242             else:
#    1243                 # object dtype
# -> 1244                 return "{x}".format(x=formatter(x))
#    1245
#    1246         vals = self.values
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1220             self.formatter
#    1221             if self.formatter is not None
# -> 1222             else (lambda x: pprint_thing(x, escape_chars=("\t", "\r", "\n")))
#    1223         )
#    1224
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         result = "'{thing}'".format(thing=as_escaped_string(thing))
#     229     else:
# --> 230         result = as_escaped_string(thing)
#     231
#     232     return result
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\printing.py in as_escaped_string(thing, escape_chars)
#     204             escape_chars = escape_chars or tuple()
#     205
# --> 206         result = str(thing)
#     207         for c in escape_chars:
#     208             result = result.replace(c, translate[c])
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\core\series.py in __repr__(self)
#    1369             min_rows=min_rows,
#    1370             max_rows=max_rows,
# -> 1371             length=show_dimensions,
#    1372         )
#    1373         result = buf.getvalue()
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\core\series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     359
#     360         fmt_index, have_header = self._get_formatted_index()
# --> 361         fmt_values = self._get_formatted_values()
#     362
#     363         if self.truncate_v:
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_values(self)
#     346             None,
#     347             float_format=self.float_format,
# --> 348             na_rep=self.na_rep,
#     349         )
#     350
#
# ... last 11 frames repeated, from the frame below ...
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# RecursionError: maximum recursion depth exceeded
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# F:\InstalledPrograms\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     732                 render_links=False,
#     733             )
# --> 734             return formatter.to_html(notebook=True)
#     735         else:
#     736             return None
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, buf, encoding, classes, notebook, border)
#     983         Klass = NotebookFormatter if notebook else HTMLFormatter
#     984         return Klass(self, classes=classes, border=border).get_result(
# --> 985             buf=buf, encoding=encoding
#     986         )
#     987
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\html.py in write_result(self, buf)
#     205
#     206     def write_result(self, buf: IO[str]) -> None:
# --> 207         buffer_put_lines(buf, self.render())
#     208
#     209     def _write_table(self, indent: int = 0) -> None:
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\html.py in render(self)
#     610         self.write("<div>")
#     611         self.write_style()
# --> 612         super().render()
#     613         self.write("</div>")
#     614         return self.elements
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\html.py in render(self)
#     192
#     193     def render(self) -> List[str]:
# --> 194         self._write_table()
#     195
#     196         if self.should_show_dimensions:
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_table(self, indent)
#     237             self._write_header(indent + self.indent_delta)
#     238
# --> 239         self._write_body(indent + self.indent_delta)
#     240
#     241         self.write("</table>", indent)
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_body(self, indent)
#     383     def _write_body(self, indent: int) -> None:
#     384         self.write("<tbody>", indent)
# --> 385         fmt_values = self._get_formatted_values()
#     386
#     387         # write values
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\html.py in _get_formatted_values(self)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\html.py in <dictcomp>(.0)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_col(self, i)
#     954             na_rep=self.na_rep,
#     955             space=self.col_space,
# --> 956             decimal=self.decimal,
#     957         )
#     958
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1258         for i, v in enumerate(vals):
#    1259             if not is_float_type[i] and leading_space:
# -> 1260                 fmt_values.append(" {v}".format(v=_format(v)))
#    1261             elif is_float_type[i]:
#    1262                 fmt_values.append(float_format(v))
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1242             else:
#    1243                 # object dtype
# -> 1244                 return "{x}".format(x=formatter(x))
#    1245
#    1246         vals = self.values
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1220             self.formatter
#    1221             if self.formatter is not None
# -> 1222             else (lambda x: pprint_thing(x, escape_chars=("\t", "\r", "\n")))
#    1223         )
#    1224
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         result = "'{thing}'".format(thing=as_escaped_string(thing))
#     229     else:
# --> 230         result = as_escaped_string(thing)
#     231
#     232     return result
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\printing.py in as_escaped_string(thing, escape_chars)
#     204             escape_chars = escape_chars or tuple()
#     205
# --> 206         result = str(thing)
#     207         for c in escape_chars:
#     208             result = result.replace(c, translate[c])
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\core\series.py in __repr__(self)
#    1369             min_rows=min_rows,
#    1370             max_rows=max_rows,
# -> 1371             length=show_dimensions,
#    1372         )
#    1373         result = buf.getvalue()
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\core\series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     359
#     360         fmt_index, have_header = self._get_formatted_index()
# --> 361         fmt_values = self._get_formatted_values()
#     362
#     363         if self.truncate_v:
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_values(self)
#     346             None,
#     347             float_format=self.float_format,
# --> 348             na_rep=self.na_rep,
#     349         )
#     350
#
# ... last 11 frames repeated, from the frame below ...
#
# F:\InstalledPrograms\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# RecursionError: maximum recursion depth exceeded
